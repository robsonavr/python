# %% [markdown]
# # Curso de python do Zero ao DS

# %%
#importando bibliotecas
import pandas as pd

# %%
df = pd.read_csv(r'kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
print(df.shape)
# Out:
# (21613, 21)

# %%
print(df.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
print(df[['id', 'price']].sort_values('price', ascending=False))
# Out:
#                id      price
# 7252   6762700020  7700000.0
# 3914   9808700762  7062500.0
# 9254   9208900037  6885000.0
# 4411   2470100110  5570000.0
# 1448   8907500070  5350000.0
# ...           ...        ...
# 8274   3883800011    82000.0
# 16198  3028200080    81000.0
# 465    8658300340    80000.0
# 15293    40000362    78000.0
# 1149   3421079032    75000.0
#
# [21613 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%dT')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# data do imovel mais antigo
df.sort_values('date', ascending=True)['date'].min()
# Out:
# Timestamp('2014-05-02 00:00:00')

# %%
# quantos imoveis tem o numero maximo de andares
print(f"Quantidade de imóveis com o número máximo de andares: \
{len(df[df['floors'] == df['floors'].max()])} imóveis")
# Out:
# Quantidade de imóveis com o número máximo de andares: 8 imóveis

# %%
df.iloc[0:10, 0:3]
# Out:
#            id       date      price
# 0  7129300520 2014-10-13   221900.0
# 1  6414100192 2014-12-09   538000.0
# 2  5631500400 2015-02-25   180000.0
# 3  2487200875 2014-12-09   604000.0
# 4  1954400510 2015-02-18   510000.0
# 5  7237550310 2014-05-12  1225000.0
# 6  1321400060 2014-06-27   257500.0
# 7  2008000270 2015-01-15   291850.0
# 8  2414600126 2015-04-15   229500.0
# 9  3793500160 2015-03-12   323000.0

# %%
# selecao de linhas e colunas atraves do index
df.iloc[0:10, :]
# Out:
#            id       date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13   221900.0         3       1.00         1180
# 1  6414100192 2014-12-09   538000.0         3       2.25         2570
# 2  5631500400 2015-02-25   180000.0         2       1.00          770
# 3  2487200875 2014-12-09   604000.0         4       3.00         1960
# 4  1954400510 2015-02-18   510000.0         3       2.00         1680
# 5  7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6  1321400060 2014-06-27   257500.0         3       2.25         1715
# 7  2008000270 2015-01-15   291850.0         3       1.50         1060
# 8  2414600126 2015-04-15   229500.0         3       1.00         1780
# 9  3793500160 2015-03-12   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# ...

# %%
# selecao das linhas e nome da coluna
df.loc[0:10, ['price', 'id', 'date']]
# Out:
#         price          id       date
# 0    221900.0  7129300520 2014-10-13
# 1    538000.0  6414100192 2014-12-09
# 2    180000.0  5631500400 2015-02-25
# 3    604000.0  2487200875 2014-12-09
# 4    510000.0  1954400510 2015-02-18
# 5   1225000.0  7237550310 2014-05-12
# 6    257500.0  1321400060 2014-06-27
# 7    291850.0  2008000270 2015-01-15
# 8    229500.0  2414600126 2015-04-15
# 9    323000.0  3793500160 2015-03-12
# 10   662500.0  1736800520 2015-04-03

# %%
# selecao atraves de indices boleanos 1 ou 0 / True ou False
""" id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15' """
cols = [True, True, True, True, False, False, False, False, False, False, False, \
        False, False, False, False, False, False, False, False, False, False]

# %%
df.loc[0:10, cols]
# Out:
#             id       date      price  bedrooms
# 0   7129300520 2014-10-13   221900.0         3
# 1   6414100192 2014-12-09   538000.0         3
# 2   5631500400 2015-02-25   180000.0         2
# 3   2487200875 2014-12-09   604000.0         4
# 4   1954400510 2015-02-18   510000.0         3
# 5   7237550310 2014-05-12  1225000.0         4
# 6   1321400060 2014-06-27   257500.0         3
# 7   2008000270 2015-01-15   291850.0         3
# 8   2414600126 2015-04-15   229500.0         3
# 9   3793500160 2015-03-12   323000.0         3
# 10  1736800520 2015-04-03   662500.0         3

# %%
# classicacao do nivel 
df['level'] = 'standard'
df.loc[df['price'] > 540e3, 'level'] = 'high_level'
df.loc[df['price'] < 540e3, 'level'] = 'low_level'
df['level']
# Out:
# 0         low_level
# 1         low_level
# 2         low_level
# 3        high_level
# 4         low_level
#             ...
# 21608     low_level
# 21609     low_level
# 21610     low_level
# 21611     low_level
# 21612     low_level
# Name: level, Length: 21613, dtype: object

# %%
# relatorio ordenado pelo preco
report = df[['id', 'date', 'price', 'bedrooms', 'sqft_lot', 'level']].sort_values('price', ascending=False)

# %%
# salvando relatorio em um arquivo csv
report.to_csv('report_aula2.csv', index=False)

# %% [markdown]
# ## Desenhando um mapa

# %%
#importando bibliotecas
import plotly.express as px

# %%
data_mapa = df[['id', 'lat', 'long', 'price']]

# %%
data_mapa.head()
# Out:
#            id      lat     long     price
# 0  7129300520  47.5112 -122.257  221900.0
# 1  6414100192  47.7210 -122.319  538000.0
# 2  5631500400  47.7379 -122.233  180000.0
# 3  2487200875  47.5208 -122.393  604000.0
# 4  1954400510  47.6168 -122.045  510000.0

# %%
# for index, colecao in df.iterrows():
#     marcador.add_child(folium.Marker([colecao['lat'], colecao['long']],
#                               popup=str(colecao['id']),
#                               tooltip=colecao['level'],
#                               icon=folium.Icon(color='green', icon='info-sign'))).add_to(mapa)

# %%
# for i in range(0,len(df)):
#    folium.Circle(
#       location=[df.iloc[i]['lat'], df.iloc[i]['long']],
#       popup=df.iloc[i]['id'],
#       radius=float(df.iloc[i]['price']),
#       color='crimson',
#       fill=True,
#       fill_color='crimson'
#    ).add_to(mapa)

# %%
mapa = px.scatter_mapbox(data_mapa, lat='lat', lon='long', 
    hover_name='id',
    hover_data=['price'],
    zoom=10, height=300)
mapa.update_layout(mapbox_style='open-street-map')
mapa.update_layout(height=800, margin={'r':0, 'l':0, 't':0, 'b':0})
mapa.write_html('mapa_house.html')

# %% [markdown]
# ### Perguntas aula 1
# 1. Quantas casas estão disponíveis para compra?
# 2. Quantos atributos as casas possuem?
# 3. Quais são os atributos das casas?
# 4. Qual a casa mais cara ( casa com o maior valor de venda )?
# 5. Qual a casa com o maior número de quartos?
# 6. Qual a soma total de quartos do conjunto de dados?
# 7. Quantas casas possuem 2 banheiros?
# 8. Qual o preço médio de todas as casas no conjunto de dados?
# 9. Qual o preço médio de casas com 2 banheiros?
# 10. Qual o preço mínimo entre as casas com 3 quartos?
# 11. Quantas casas possuem mais de 300 metros quadrados na sala de estar?
# 12. Quantas casas tem mais de 2 andares?
# 13. Quantas casas tem vista para o mar?
# 14. Das casas com vista para o mar, quantas tem 3 quartos?
# 15. Das casas com mais de 300 metros quadrados de sala de estar, quantas tem mais de 2 banheiros?

# %%
# Quantas casas estão disponíveis para compra?
# Quantos atributos as casas possuem?
print(f'Temos {df.shape[0]} casas disponíveis e as casas possuem {df.shape[1]} atributos')
# Out:
# Temos 21613 casas disponíveis e as casas possuem 22 atributos

# %%
# Quais são os atributos das casas?
for atributo in df.columns:
    print(atributo)
# Out:
# id
# date
# price
# bedrooms
# bathrooms
# sqft_living
# sqft_lot
# floors
# waterfront
# view
# condition
# grade
# sqft_above
# sqft_basement
# yr_built
# yr_renovated
# zipcode
# lat
# long
# sqft_living15
# sqft_lot15
# level

# %%
# Qual a casa mais cara ( casa com o maior valor de venda )?
df.loc[df['price'] == df['price'].max()]
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020 2014-10-13  7700000.0         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 7252     27600     2.5           0     3  ...      8570.0           3480
#
#       yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 7252      1910          1987    98102  47.6298 -122.323           3940
#
#       sqft_lot15       level
# 7252        8800  high_level
#
# [1 rows x 22 columns]

# %%
# Qual a casa com o maior número de quartos?
df.loc[df['bedrooms'] == df['bedrooms'].max()]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 15870      6000     1.0           0     0  ...      1040.0            580
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15870      1947             0    98103  47.6878 -122.331           1330
#
#        sqft_lot15       level
# 15870        4700  high_level
#
# [1 rows x 22 columns]

# %%
#Qual a soma total de quartos do conjunto de dados?
print(f"Temos um total de {df['bedrooms'].sum()} quartos disponíveis")
# Out:
# Temos um total de 72854 quartos disponíveis

# %%
# Quantas casas possuem 2 banheiros?
print(f"O total de casas com 2 banheiros é {df.loc[df['bathrooms'] == 2].count()[0]} casas")
# Out:
# O total de casas com 2 banheiros é 1930 casas

# %%
# Qual o preço médio de todas as casas no conjunto de dados?
print(f"O valor do preço médio das casas é de R${df['price'].mean():,.2f}")
# Out:
# O valor do preço médio das casas é de R$540,088.14

# %%
# Qual o preço médio de casas com 2 banheiros?
print(f"Preço médio das casas com 2 banheiros R${df.loc[df['bathrooms'] == 2, 'price'].mean():,.2f}")
# Out:
# Preço médio das casas com 2 banheiros R$457,889.72

# %%
# Qual o preço mínimo entre as casas com 3 quartos?
print(f"O menor valor das casas com 3 quartos é de R${df.loc[df['bedrooms'] == 3, 'price'].min():,.2f}")
# Out:
# O menor valor das casas com 3 quartos é de R$82,000.00

# %%
# Quantas casas possuem mais de 300 metros quadrados na sala de estar?
print(f"{df.loc[df['sqft_living'] > (300*10.764)].count()[0]} casas tem mais de 300 m2")
# Out:
# 2258 casas tem mais de 300 m2

# %%
# Quantas casas tem mais de 2 andares?
print(f"{df.loc[df['floors'] >= 2].count()[0]} casas tem mais de 2 andares")
# Out:
# 9023 casas tem mais de 2 andares

# %%
# Quantas casas tem vista para o mar?
print(f"{df.loc[df['waterfront'] == 1].count()[0]} casas tem vista para o mar")
# Out:
# 163 casas tem vista para o mar

# %%
# Das casas com vista para o mar, quantas tem 3 quartos?
print(f"{df.loc[(df['waterfront'] == 1) & (df['bedrooms'] == 3)].count()[0]} casas com 3 quartos tem vista para o mar")
# Out:
# 64 casas com 3 quartos tem vista para o mar

# %%
# Das casas com mais de 300 metros quadrados de sala de estar, quantas tem mais de 2 banheiros?
print(f"{df.loc[(df['sqft_living'] > (300*10.764)) & (df['bathrooms'] >= 2)].count()[0]} casas tem mais de 300 m2 tem mais de 2 banheiros")
# Out:
# 2219 casas tem mais de 300 m2 tem mais de 2 banheiros

# %% [markdown]
# ### Perguntas aula 3

# %%
# 1. Qual o número de imoveis por ano de construção?
df[['id', 'yr_built']].groupby('yr_built').count()
# Out:
#            id
# yr_built
# 1900       87
# 1901       29
# 1902       27
# 1903       46
# 1904       45
# ...       ...
# 2011      130
# 2012      170
# 2013      201
# 2014      559
# 2015       38
#
# [116 rows x 1 columns]

# %%
# 2. Qual o menor número de quartos por ano de construção de imóveis?
df[['bedrooms', 'yr_built']].groupby('yr_built').min()
# Out:
#           bedrooms
# yr_built
# 1900             1
# 1901             2
# 1902             2
# 1903             1
# 1904             2
# ...            ...
# 2011             1
# 2012             2
# 2013             2
# 2014             1
# 2015             1
#
# [116 rows x 1 columns]

# %%
# 3. Qual o preço de compra mais alto por cada número de quartos?
df[['price', 'bedrooms']].groupby('bedrooms').max().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_15eb8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr>    <tr>        <th class="index_name level0" >bedrooms</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15eb8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_15eb8_row0_col0" class="data row0 col0" >1,295,650.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_15eb8_row1_col0" class="data row1 col0" >1,247,000.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb8_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_15eb8_row2_col0" class="data row2 col0" >3,278,000.00</td>
#             </tr>
# ...

# %%
# 4. Qual a soma de todos os preços de compra por número de quartos?
df[['price', 'bedrooms']].groupby('bedrooms').sum().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_efea1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr>    <tr>        <th class="index_name level0" >bedrooms</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_efea1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_efea1_row0_col0" class="data row0 col0" >5,323,550.00</td>
#             </tr>
#             <tr>
#                         <th id="T_efea1_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_efea1_row1_col0" class="data row1 col0" >63,210,934.00</td>
#             </tr>
#             <tr>
#                         <th id="T_efea1_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_efea1_row2_col0" class="data row2 col0" >1,107,788,602.00</td>
#             </tr>
# ...

# %%
# 5. Qual a soma de todos os preços de compra por número de quartos e banheiros?
df[['price', 'bedrooms', 'bathrooms']].groupby(['bedrooms', 'bathrooms']).sum().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_5d435_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr>    <tr>        <th class="index_name level0" >bedrooms</th>        <th class="index_name level1" >bathrooms</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d435_level0_row0" class="row_heading level0 row0" rowspan="5">0</th>
#                         <th id="T_5d435_level1_row0" class="row_heading level1 row0" >0.0</th>
#                         <td id="T_5d435_row0_col0" class="data row0 col0" >3,642,600.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_5d435_level1_row1" class="row_heading level1 row1" >0.75</th>
#                         <td id="T_5d435_row1_col0" class="data row1 col0" >265,000.00</td>
#             </tr>
#             <tr>
# ...

# %%
# 6.  Qual o tamanho médio de salas dos imóveis por ano de construção?
df[['sqft_living', 'yr_built']].groupby('yr_built').mean()
# Out:
#           sqft_living
# yr_built
# 1900      1732.011494
# 1901      1763.620690
# 1902      1919.629630
# 1903      1507.739130
# 1904      1603.177778
# ...               ...
# 2011      2313.684615
# 2012      2378.741176
# 2013      2636.592040
# 2014      2615.389982
# 2015      2596.315789
#
# [116 rows x 1 columns]

# %%
# 7. Qual o tamanho mediano das salas dos imóveis por ano de construção?
df[['sqft_living', 'yr_built']].groupby('yr_built').median()
# Out:
#           sqft_living
# yr_built
# 1900           1540.0
# 1901           1610.0
# 1902           1600.0
# 1903           1505.0
# 1904           1280.0
# ...               ...
# 2011           2270.0
# 2012           2237.5
# 2013           2580.0
# 2014           2650.0
# 2015           2590.0
#
# [116 rows x 1 columns]

# %%
# 8. Qual o desvio padrão do tamanho das salas dos imóveis por ano de construção?
df[['sqft_living', 'yr_built']].groupby('yr_built').std()
# Out:
#           sqft_living
# yr_built
# 1900       732.944373
# 1901       668.231804
# 1902       878.659300
# 1903       469.723438
# 1904      1076.870620
# ...               ...
# 2011       804.863521
# 2012       771.430350
# 2013       883.499390
# 2014       893.810049
# 2015      1155.605425
#
# [116 rows x 1 columns]

# %%
# 9. Como é o crescimento total de preços de compras dos imoveis por ano, por dia e pela semana do ano?

# %%
# cria uma nova coluna com a seguimentação das datas
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above              float64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# level                    object
# dtype: object

# %%
df['year'] = df['date'].dt.year
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df[['year', 'price']].groupby('year').sum().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_cde15_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr>    <tr>        <th class="index_name level0" >year</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cde15_level0_row0" class="row_heading level0 row0" >2014</th>
#                         <td id="T_cde15_row0_col0" class="data row0 col0" >7,889,841,842.00</td>
#             </tr>
#             <tr>
#                         <th id="T_cde15_level0_row1" class="row_heading level0 row1" >2015</th>
#                         <td id="T_cde15_row1_col0" class="data row1 col0" >3,783,083,166.00</td>
#             </tr>
#     </tbody></table>

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
by_year = df[['year', 'price']].groupby('year').sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.bar(by_year['year'], by_year['price'])
plt.show()

# %%
by_day = df[['date', 'price']].groupby('date').mean().reset_index()
print(by_day.head())
plt.figure(figsize=(20, 6))
plt.plot(by_day['date'], by_day['price'])
plt.show()
# Out:
#         date          price
# 0 2014-05-02  526251.492537
# 1 2014-05-03  466970.000000
# 2 2014-05-04  576690.000000
# 3 2014-05-05  580938.607143
# 4 2014-05-06  534047.903614

# %%
df['year-week'] = df['date'].dt.strftime('%Y-%U')
year_week = df[['year-week', 'price']].groupby('year-week').mean().reset_index()
print(year_week.head())
plt.figure(figsize=(20, 6))
plt.plot(year_week['year-week'], year_week['price'])
plt.xticks(rotation=60)
plt.show()
# Out:
#   year-week          price
# 0   2014-17  522911.690141
# 1   2014-18  543577.094907
# 2   2014-19  558750.111111
# 3   2014-20  528149.942387
# 4   2014-21  572404.350267

# %%
from matplotlib import gridspec

fig = plt.figure(figsize=(20,6))
specs = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)
ax1 = fig.add_subplot(specs[0, 0])
ax2 = fig.add_subplot(specs[1, 0])
ax3 = fig.add_subplot(specs[1, 1])

ax1.bar(by_year['year'], by_year['price'])
ax2.plot(by_day['date'], by_day['price'])
ax3.plot(year_week['year-week'], year_week['price'])
plt.xticks(rotation=60)
plt.show()

# %%
# 10. Faça um mapa que identifique as casas com maior preço

# %%
houses = df[['id', 'lat', 'long', 'price']]
mapa = px.scatter_mapbox(houses, lat='lat', lon='long', 
    hover_name='id',
    hover_data=['price'],
    size_max=15,
    size='price',
    color_continuous_scale=px.colors.cyclical.IceFire,
    zoom=10, height=300)
mapa.update_layout(mapbox_style='open-street-map')
mapa.update_layout(height=800, margin={'r':0, 'l':0, 't':0, 'b':0})
mapa.write_html('mapa2_house.html')

# %% [markdown]
# ### Exercícios

# %%
# 1. Crie uma nova coluna chamada 'dormitory_type'
# * se o valor da coluna 'berdrooms' for igual a 1 -> studio 
# * se o valor da coluna 'berdrooms' for igual a 2 -> apartament 
# * se o valor da coluna 'berdrooms' > 2 -> house
df['dormitory_type'] = 'house'
df['bedrooms'] = pd.to_numeric(df['bedrooms'])

# %%
df.loc[df['bedrooms'] <= 1, 'dormitory_type'] = 'studio'
df.loc[df['bedrooms'] == 2, 'dormitory_type'] = 'apartament'
df.sample(5)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7574    625069064 2015-05-07   625000.0         3       2.25         2570
# 17413  5212000020 2015-03-24   630100.0         4       2.75         1910
# 13484  4040800120 2015-02-11   447000.0         3       1.00         1220
# 18771  3216900100 2014-06-12   315000.0         3       2.50         1880
# 8049   4134300175 2015-04-17  1851000.0         4       2.50         4120
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode  \
# 7574      47480     1.0           0     0  ...             0    98053
# 17413     11356     1.0           0     0  ...             0    98033
# 13484      7200     1.0           0     0  ...             0    98008
# 18771      7000     2.0           0     0  ...             0    98031
# 8049      14866     1.0           1     4  ...             0    98006
#
#            lat     long  sqft_living15  sqft_lot15       level  year  \
# ...

# %%
# 2. Faça um gráfico de barras que represente a soma dos preços pelo número de quartos
price_bedrooms = df[['bedrooms', 'price']].groupby('bedrooms').sum().reset_index()
plt.figure(figsize=(10,6))
plt.bar(price_bedrooms['bedrooms'],  price_bedrooms['price'])
# Out:
# <BarContainer object of 13 artists>

# %%
# 3. Faça um gráfico de linhas que represente a média dos preços pelo ano da construção dos imóveis
price_built = df[['price', 'yr_built']].groupby('yr_built').mean().reset_index()
plt.figure(figsize=(10,6))
plt.bar(price_built['yr_built'], price_built['price'])
# Out:
# <BarContainer object of 116 artists>

# %%
# 4. Faça um gráfico de barras que represente a média dos preços pelo tipo dos dormitórios
price_type = df[['price', 'dormitory_type']].groupby('dormitory_type').mean().reset_index()
plt.bar(price_type['dormitory_type'], price_type['price'])
# Out:
# <BarContainer object of 3 artists>

# %%
# 5. Faça um gráfico de linha que mostre a evolução da média dos preços pelo ano da reforma dos imíveis, a partir do ano de 1930
evo_price = df.loc[df['yr_renovated'] > 1930, ['yr_renovated', 'price']].groupby('yr_renovated').mean().reset_index()
plt.figure(figsize=(20,6))
plt.plot(evo_price['yr_renovated'], evo_price['price'])

# %%
#6. Faça uma tabela que mostre a média dos preços por ano de construção e tipo de dormitório dos imóveis
df[['yr_built', 'dormitory_type', 'price']].groupby(['yr_built', 'dormitory_type']).mean().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_23714_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr>    <tr>        <th class="index_name level0" >yr_built</th>        <th class="index_name level1" >dormitory_type</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23714_level0_row0" class="row_heading level0 row0" rowspan="3">1900</th>
#                         <th id="T_23714_level1_row0" class="row_heading level1 row0" >apartament</th>
#                         <td id="T_23714_row0_col0" class="data row0 col0" >589,533.33</td>
#             </tr>
#             <tr>
#                                 <th id="T_23714_level1_row1" class="row_heading level1 row1" >house</th>
#                         <td id="T_23714_row1_col0" class="data row1 col0" >584,854.27</td>
#             </tr>
#             <tr>
# ...

# %%
# 7. Crie um Dashboard com os gráficos das questões 02,03,04 (1 linha e 2 colunas)
# 8. Crie um Dashboard com os gráficos das questões 02 e 04 (2 colunas)
# 9. Crie um Dashboard com os gráficos das questões 03 e 5 (2 linhas)
# 10. Faça um gráfico com o tamanho dos pontos sendo igual ao tamanho da sala de estar

# %%
living = df[['id', 'lat', 'long', 'sqft_living']]
mapa = px.scatter_mapbox(living, lat='lat', lon='long', 
    hover_name='id',
    hover_data=['sqft_living'],
    size_max=15,
    size='sqft_living',
    color_continuous_scale=px.colors.cyclical.IceFire,
    zoom=10, height=300)
mapa.update_layout(mapbox_style='open-street-map')
mapa.update_layout(height=800, margin={'r':0, 'l':0, 't':0, 'b':0})
mapa.write_html('mapa3_house.html')

# %% [markdown]
# ### Aula 04: Estruturas de controle

# %%
# 1. Qual a quantidade de imóveis por nível?
#  - Nivel 0: Preço entre R$ 0.00 e R$ 321.950
#  - Nivel 1: Preço entre R$ 321.950 e R$ 450.000
#  - Nivel 2: Preço entre R$ 450.000 e R$ 645.000
#  - Nivel 3: Preço entre R$ Acima de R$ 645.000

import numpy as np

df['nivel'] = np.nan
df.loc[(df['price'] > 0) & (df['price'] < 321950), 'nivel'] = 'nivel_0'
df.loc[(df['price'] > 321950) & (df['price'] < 450e3), 'nivel'] = 'nivel_1'
df.loc[(df['price'] > 450e3) & (df['price'] < 645e3), 'nivel'] = 'nivel_2'
df.loc[(df['price'] > 645e3), 'nivel'] = 'nivel_3'
df['nivel'].sample(5)
# Out:
# 6217     nivel_0
# 1410     nivel_3
# 14753    nivel_0
# 11476    nivel_0
# 13343    nivel_1
# Name: nivel, dtype: object

# %%
df['nivel'].value_counts()
# Out:
# nivel_0    5403
# nivel_3    5373
# nivel_2    5336
# nivel_1    5288
# Name: nivel, dtype: int64

# %%
# 2. Adicione as seguintes informações ao imóvel:
#  - Nome da Rua
#  - Número do imóvel
#  - O nome do Bairro
#  - O nome da cidade
#  - O nome do estado

# %%
# 3. Adicione o nível do imóvel no mapa como uma cor

# %%
# 4. Adicione o preço do imóvel como o tamanho do ponto no mapa

# %%
# 5. Adicione opções de filtros para fazer as próprias análises
#   - Eu quero escolher visualizar imóveis com vista para água ou não
#   - Eu quero escolher visualizar imóveis até um certo valor de preço

# %%
# 6. Adicionar opções de filtros no últimos dashboard enviado:
#    - Visualizar somente valores a partir de uma data disponível para compra
