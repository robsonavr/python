# %% [markdown]
# # Base de dados do Prouni

# %%
#importacao das bibliotecas
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv(r'cursos-prouni.csv', encoding='utf8')

print(f'Total da base de dados {df.shape[0]} linhas e {df.shape[1]} colunas')

print(df.head())
# Out:
# Total da base de dados 41447 linhas e 20 colunas
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
print(df.describe())
# Out:
#         mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id     campus_id  \
# count          8828.000000         13041.000000  4.144700e+04  4.144700e+04
# mean              1.873018             8.632544  4.207360e+13  6.786530e+05
# std               2.336403            18.372991  6.061552e+13  6.398410e+05
# min               1.000000             1.000000  2.248801e+07  2.240000e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  41447 non-null  object
#  1   turno                 41447 non-null  object
#  2   mensalidade           41447 non-null  float64
#  3   bolsa_integral_cotas  32520 non-null  float64
#  4   bolsa_integral_ampla  25404 non-null  float64
#  5   bolsa_parcial_cotas   8828 non-null   float64
#  6   bolsa_parcial_ampla   13041 non-null  float64
#  7   curso_id              41447 non-null  int64
#  8   curso_busca           41447 non-null  object
#  9   cidade_busca          41447 non-null  object
#  10  uf_busca              41447 non-null  object
#  11  cidade_filtro         41447 non-null  object
#  12  universidade_nome     41447 non-null  object
#  13  campus_nome           41447 non-null  object
#  14  campus_id             41447 non-null  int64
# ...

# %%
#Quantidade de cursos por uf
df['uf_busca'].value_counts()
# Out:
# SP    11533
# MG     4175
# PR     3918
# RS     3060
# BA     2505
# SC     2195
# RJ     1442
# GO     1278
# PA     1201
# PE     1148
# DF     1063
# MT     1063
# ES      825
# CE      816
# MS      785
# MA      679
# PB      596
# RO      463
# AM      429
# PI      405
# TO      343
# RN      342
# AL      327
# SE      323
# AP      219
# AC      203
# RR      111
# Name: uf_busca, dtype: int64

# %%
#mensalidade de maior valor
df[df['mensalidade'] == df['mensalidade'].max()]
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
#
#        curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0  706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
#
#                    universidade_nome                         campus_nome  \
# 0  Universidade Anhanguera - UNIDERP  CAMPO GRANDE - SEDE - Miguel Couto
#
#    campus_id      nome  nota_integral_ampla  nota_integral_cotas  \
# 0     706710  Medicina               740.22               726.46
#
#    nota_parcial_ampla  nota_parcial_cotas
# 0                 NaN                 NaN

# %%
#mensalidade de menor valor
df[df['mensalidade'] == df['mensalidade'].min()][['grau', 'mensalidade', 'curso_busca', 'cidade_busca']]
# Out:
#               grau  mensalidade                 curso_busca cidade_busca
# 41444  Tecnológico        139.0  Gestão de Recursos Humanos     Brasilia
# 41445  Bacharelado        139.0              Serviço Social      Vitoria
# 41446  Tecnológico        139.0            Gestão Ambiental     Santarem

# %%
# Maior valor pela uf
df.groupby(df['uf_busca'])['mensalidade'].max()
# Out:
# uf_busca
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: mensalidade, dtype: float64

# %%
df.loc[df.groupby(df['uf_busca'])['mensalidade'].idxmax()][['grau', 'mensalidade', 'curso_busca','uf_busca', 'cidade_busca']]
# Out:
#               grau  mensalidade      curso_busca uf_busca      cidade_busca
# 4      Bacharelado      9674.34         Medicina       AC        Rio Branco
# 67     Bacharelado      7290.00         Medicina       AL            Maceio
# 627    Bacharelado      2127.05      Odontologia       AM            Manaus
# 202    Bacharelado      3607.62      Odontologia       AP            Macapa
# 9      Bacharelado      9048.00         Medicina       BA  Lauro de Freitas
# 1      Bacharelado      9836.40       Enfermagem       CE           Crateus
# 92     Bacharelado      6757.92         Medicina       DF          Brasilia
# 118    Bacharelado      6022.28         Medicina       ES          Colatina
# 102    Bacharelado      6484.47         Medicina       GO           Goiania
# 20     Bacharelado      8281.38         Medicina       MA        Imperatriz
# 7      Bacharelado      9350.00         Medicina       MG  Sao Joao Del Rei
# ...

# %%
df[(df['mensalidade'] > 1000) & (df['mensalidade'] < 1500)][['grau', 'mensalidade', 'curso_busca','uf_busca', 'cidade_busca']]
# Out:
#              grau  mensalidade              curso_busca uf_busca  \
# 2007  Bacharelado      1499.81   Engenharia de Petróleo       RS
# 2008  Bacharelado      1499.81         Engenharia Civil       RS
# 2009  Bacharelado      1499.81  Arquitetura e Urbanismo       RS
# 2010  Bacharelado      1499.81   Engenharia de Petróleo       RS
# 2011  Bacharelado      1499.81         Engenharia Civil       RS
# ...           ...          ...                      ...      ...
# 6985  Bacharelado      1000.91          Educação Física       PE
# 6986  Bacharelado      1000.69   Engenharia de Produção       PR
# 6987  Tecnológico      1000.48             Agropecuária       RS
# 6988  Bacharelado      1000.32               Enfermagem       SP
# 6989  Bacharelado      1000.03       Ciências Contábeis       RJ
#
#               cidade_busca
# 2007           Passo Fundo
# 2008               Pelotas
# 2009               Pelotas
# 2010          Porto Alegre
# 2011          Porto Alegre
# ...
